# %% [markdown]
# # Imports

# %%
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

def get_page_content(url):
    # Set up Selenium options
    options = Options()
    options.add_argument("--headless")  # Run Chrome in headless mode

    # Set up the Selenium service
    service = Service('path_to_chromedriver')  # Replace 'path_to_chromedriver' with the actual path to chromedriver executable
    service.start()

    # Set up the Chrome driver
    driver = webdriver.Chrome(service=service, options=options)  # Make sure chromedriver is in your PATH

    # Fetch the page
    driver.get(url)
    
    # Wait for the page to load (you may need to adjust the waiting time depending on the page)
    driver.implicitly_wait(10)  # Wait for 10 seconds

    # Get the page source and create a BeautifulSoup object
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    

    # Close the Chrome driver
    driver.quit()

    return soup

# %%
url = 'https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_Trading_Card_Game_expansions#Original_Series'
page_content = get_page_content(url)

# prettify() method adds indentation and line breaks to make the HTML structure more human-readable. This is particularly useful when you're working with complex HTML.
print(page_content.prettify())
# Out:
# <html class="client-js" dir="ltr" lang="en">
#  <head>
#   <script async="" src="https://d9.flashtalking.com/d9core" type="text/javascript">
#   </script>
#   <script async="" defer="" src="https://launchpad.privacymanager.io/1/launchpad.bundle.js">
#   </script>
#   <script src="https://launchpad-wrapper.privacymanager.io/69e75073-3763-483e-a64c-0d281bfd9225/launchpad-liveramp.js" type="text/javascript">
#   </script>
#   <script async="" src="https://s0.2mdn.net/instream/video/client.js" type="text/javascript">
#   </script>
#   <script async="" src="https://collector.brandmetrics.com/c.js?siteid=f9816ecc-b51b-4747-bc3e-1ea86a0677a2&amp;toploc=bulbapedia.bulbagarden.net&amp;rnd=5315646" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" src="//imasdk.googleapis.com/js/sdkloader/ima3.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.brandmetrics.com/tag/aa466d868b2742ffa2cc31bb6341dc12/cafemedia.js" type="text/javascript">
#   </script>
# ...

# %% [markdown]
# # HTML

# %%
# Convert the soup object to an HTML string
html_string = str(page_content)

# Read tables from the HTML string using pd.read_html() or read_tables()
tables = pd.read_html(html_string)

# %% [markdown]
# # Naming Tables

# %%
# Define the expansion names
ex = [
    "Original_Series",
    "Neo_Series",
    "Legendary_Collection_Series",
    "e-Card_Series",
    "EX_Series",
    "Diamond_&_Pearl_Series",
    "Platinum_Series",
    "HeartGold_&_SoulSilver_Series",
    "Call_of_Legends_Series",
    "Black_&_White_Series",
    "XY_Series",
    "Sun_& _Moon_Series",
    "Sword_&_Shield_Series",
    "Scarlet_&_Violet_Series",
    "Black_Star_Promos",
    "McDonald's_Collection",
    "POP_/_Play!_Pokemon_Prize_Packs",
    "Other_Miscellaneous_Sets"
]

# %%
expansion_names[0]['Name of Expansion'][0]
# Out:
# 'Base Set'

# %%
len(expansion_names[0]['Name of Expansion'])
# Out:
# 7

# %%
listSet = []
for i in range(0,len(expansion_names)):
    
    setName = expansion_names[i]
    
    for i in range(0,len(setName['Name of Expansion'])):
        
        word = setName['Name of Expansion'][i]
        
        listSet.append(word)

# %%
len(listSet)
# Out:
# 110

# %%
# Define the regular expression pattern
pattern = re.compile(r'^/wiki/.*_(TCG)$')

# Find all <a> elements with matching href attribute
page_content.find_all('a', href=pattern)
# Out:
# [<a href="/wiki/Bulbapedia:Project_TCG" title="Bulbapedia:Project TCG">Project TCG</a>]

# %%
# Find all <a> elements with matching href attribute
matched_links = soup.find_all('a', href=pattern)

# Extract the href attribute values
for link in matched_links:
    href = link['href']
    print(href)

# %%
# Find all <a> elements with matching href attribute
page_content.find_all('a',href = True)
# Out:
# [<a class="bg-global-nav-logo" href="https://bulbagarden.net"></a>,
#  <a class="bg-global-nav-primary-link" href="https://bulbagarden.net">News</a>,
#  <a class="bg-global-nav-primary-link bg-global-nav-primary-toggle selected" href="https://bulbapedia.bulbagarden.net/">Bulbapedia</a>,
#  <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/">Bulbapedia main page</a>,
#  <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number">National Pokédex</a>,
#  <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_name">By Name</a>,
#  <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Legendary_Pok%C3%A9mon">Legendary</a>,
#  <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Mythical_Pok%C3%A9mon">Mythical</a>,
# ...

# %%
links = page_content.find_all('a',href = True)

# Print the href attribute values
for link in links:
    href = link['href']
    print(href)
# Out:
# https://bulbagarden.net
# https://bulbagarden.net
# https://bulbapedia.bulbagarden.net/
# https://bulbapedia.bulbagarden.net/
# https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number
# https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_name
# https://bulbapedia.bulbagarden.net/wiki/Legendary_Pok%C3%A9mon
# https://bulbapedia.bulbagarden.net/wiki/Mythical_Pok%C3%A9mon
# https://bulbapedia.bulbagarden.net/wiki/Event_Pok%C3%A9mon
# https://bulbapedia.bulbagarden.net/wiki/Noble_Pokémon
# https://bulbapedia.bulbagarden.net/wiki/Gigantamax
# https://bulbapedia.bulbagarden.net/wiki/Alpha_Pokémon
# https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon
# https://bulbapedia.bulbagarden.net/wiki/Type
# https://bulbapedia.bulbagarden.net/wiki/Type#Type_chart
# https://bulbapedia.bulbagarden.net/wiki/Category:Abilities
# https://bulbapedia.bulbagarden.net/wiki/Nature#List_of_Natures
# https://bulbapedia.bulbagarden.net/wiki/Status_condition
# ...

# %%
<div id="toc" class="toc" role="navigation" aria-labelledby="mw-toc-heading"><input type="checkbox" role="button" id="toctogglecheckbox" class="toctogglecheckbox" style="display:none"><div class="toctitle" lang="en" dir="ltr"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
<ul>
<li class="toclevel-1 tocsection-1"><a href="#Main_Expansions"><span class="tocnumber">1</span> <span class="toctext">Main Expansions</span></a>
<ul>
<li class="toclevel-2 tocsection-2"><a href="#Original_Series"><span class="tocnumber">1.1</span> <span class="toctext">Original Series</span></a></li>
<li class="toclevel-2 tocsection-3"><a href="#Neo_Series"><span class="tocnumber">1.2</span> <span class="toctext">Neo Series</span></a></li>
<li class="toclevel-2 tocsection-4"><a href="#Legendary_Collection_Series"><span class="tocnumber">1.3</span> <span class="toctext">Legendary Collection Series</span></a></li>
<li class="toclevel-2 tocsection-5"><a href="#e-Card_Series"><span class="tocnumber">1.4</span> <span class="toctext">e-Card Series</span></a></li>
<li class="toclevel-2 tocsection-6"><a href="#EX_Series"><span class="tocnumber">1.5</span> <span class="toctext">EX Series</span></a></li>
